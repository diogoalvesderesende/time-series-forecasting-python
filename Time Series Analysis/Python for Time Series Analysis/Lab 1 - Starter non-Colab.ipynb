# %% [markdown]
# # Python Lab 1 (Starter, local version) — Load and Explore the Data
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/diogoalvesderesende/time-series-forecasting-python/blob/main/Time%20Series%20Analysis/Python%20for%20Time%20Series%20Analysis/Lab%201%20-%20Starter%20non-Colab.ipynb)
#
# Same as `Lab 1 - Starter.ipynb`, with the Google Drive mount removed.
#
# Use this one if you are running Jupyter on your own machine instead of Colab. It reads `train.csv`
# from the same folder as the notebook.
#
# | | |
# |---|---|
# | **Course section** | Python for Time Series Analysis |
# | **Data** | `train.csv` (retail store sales) |
# | **Runs on** | CPU, locally |
#
# ## Roadmap
#
# 1. Import pandas
# 2. Load `train.csv` and preview it
# 3. Inspect the structure with `df.info()`
# 4. Count the values in `StateHoliday`
# 5. Binarise `StateHoliday` so that `a`, `b` and `c` all become 1
#
# ---
#
# Part of **[Master Time Series Analysis and Forecasting with Python](https://www.udemy.com/course/forecasting-python/?referralCode=63045C9CC807EB1EBD9A)** · [All notebooks](https://github.com/diogoalvesderesende/time-series-forecasting-python)

# %%
# --- Setup -------------------------------------------------------------------
# Works three ways, in this order:
#   1. Google Drive, if you copied the course folder there (what the videos show)
#   2. The notebook's own folder, if you cloned the repository
#   3. Downloading this section's data from GitHub, if neither of the above
import os
import urllib.parse
import urllib.request

DRIVE_FOLDER = "/content/drive/MyDrive/Python - Time Series Forecasting/Time Series Analysis/Python for Time Series Analysis"
REPO_FOLDER = "Time Series Analysis/Python for Time Series Analysis"
DATA_FILES = ["train.csv"]
RAW = "https://raw.githubusercontent.com/diogoalvesderesende/time-series-forecasting-python/main/"

try:
    from google.colab import drive
    drive.mount("/content/drive")
    if os.path.isdir(DRIVE_FOLDER):
        os.chdir(DRIVE_FOLDER)
except ImportError:
    pass  # not running on Colab - stay where we are

# Fetch anything that is not already next to the notebook.
for name in DATA_FILES:
    if not os.path.exists(name):
        print(f"Downloading {name} ...")
        urllib.request.urlretrieve(RAW + urllib.parse.quote(REPO_FOLDER + "/" + name), name)

print("Working directory:", os.getcwd())

# %% [markdown]
# # Lab 1 – Load and Explore the Data

# %%
# Task 1: Import the pandas library for data manipulation.

# %%
# Task 2: Load the 'train.csv' file into a DataFrame called df and preview the first rows.

# %%
# Task 3: Inspect the structure of the DataFrame using df.info().

# %%
# Task 4: Print the unique values in 'StateHoliday' and their counts.

# %%
# Task 5: Binarize the 'StateHoliday' column so that any of 'a', 'b', or 'c' becomes 1 and 0 stays 0.
# Then, print the updated value counts.
