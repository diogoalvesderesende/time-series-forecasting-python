# %% [markdown]
# # Air Miles Capstone — Task 5 Solution: Forecast
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/diogoalvesderesende/time-series-forecasting-python/blob/main/Time%20Series%20Analysis/CAPSTONE%20PROJECT%20-%20Airmiles/Task%20Solutions/Task%205.ipynb)
#
# Forecast as many steps as there are rows in the test set.
#
# | | |
# |---|---|
# | **Course section** | Holt-Winters Capstone Project: Air miles |
# | **Data** | `airmiles.csv` (monthly) |
# | **Exercise** | `../Starter Code.ipynb` |
#
# ## Note
#
# `forecast(steps)` continues from the end of the training data, so the output lines up with the test index.
#
# > This notebook holds the answer to one task only. It continues from the state left by the previous
# > tasks, so it will not run standalone. Run the tasks in order, or open
# > `Solutions Udemy Workspace - Airmiles.ipynb` for the whole thing in one place.
#
# ---
#
# Part of **[Master Time Series Analysis and Forecasting with Python](https://www.udemy.com/course/forecasting-python/?referralCode=63045C9CC807EB1EBD9A)** · [All notebooks](https://github.com/diogoalvesderesende/time-series-forecasting-python)

# %%
# Forecast future values for the length of the test set
predictions = model.forecast(steps = len(test)).rename("Holt-Winters")
predictions
